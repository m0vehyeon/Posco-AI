# %%
import cv2, os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.utils import shuffle
import pandas as pd

# %% [markdown]
# First, download data from:
#
# https://drive.google.com/file/d/0B0d9ZiqAgFkiOHR1NTJhWVJMNEU/view
#
# and save the downloaded data1 folder in the current directory.

# %%
dir_data = "dataset1/"
dir_seg = dir_data + "/annotations_prepped_train/"
dir_img = dir_data + "/images_prepped_train/"

# %% [markdown]
# Visualize a single segmentation image
#
# In this data, there are 12 segmentation classes and the image is from a driving car.

# %%
## seaborn has white grid by default so I will get rid of this.
sns.set_style("whitegrid", {'axes.grid' : False})


ldseg = np.array(os.listdir(dir_seg))
## pick the first image file
fnm = ldseg[0]
print(fnm)

## read in the original image and segmentation labels
seg = cv2.imread(dir_seg + fnm ) # (360, 480, 3)
img_is = cv2.imread(dir_img + fnm )
print("seg.shape={}, img_is.shape={}".format(seg.shape,img_is.shape))

## Check the number of labels
mi, ma = np.min(seg), np.max(seg)
n_classes = ma - mi + 1
print("minimum seg = {}, maximum seg = {}, Total number of segmentation classes = {}".format(mi,ma, n_classes))

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1,1,1)
ax.imshow(img_is)
ax.set_title("original image")
plt.show()

fig = plt.figure(figsize=(15,10))
for k in range(mi,ma+1):
    ax = fig.add_subplot(3,n_classes/3,k+1)
    ax.imshow((seg == k)*1.0)
    ax.set_title("label = {}".format(k))


plt.show()
# Out:
# 0016E5_07230.png
# seg.shape=(360, 480, 3), img_is.shape=(360, 480, 3)
# minimum seg = 0, maximum seg = 11, Total number of segmentation classes = 12

# %% [markdown]
# **Data preprocessing: Resize image**
#
# To simplify the problem, I will reshape all the images to the same size: (224,224).
# Why (224,224)?
# This is the iamge shape used in VGG and FCN model in this blog uses a network that takes advantage of VGG structure.
# The FCN model becomes easier to explain when the image shape is (224,224).
# However, FCN does not requires the image shape to be (224,224).
#
# Let's visualize how the resizing make the images look like. The images look fine.

# %%
def give_color_to_seg_img(seg,n_classes):
    '''
    seg : (input_width,input_height,3)
    '''
    
    if len(seg.shape)==3:
        seg = seg[:,:,0]
    seg_img = np.zeros( (seg.shape[0],seg.shape[1],3) ).astype('float')
    colors = sns.color_palette("hls", n_classes)
    
    for c in range(n_classes):
        segc = (seg == c)
        seg_img[:,:,0] += (segc*( colors[c][0] ))
        seg_img[:,:,1] += (segc*( colors[c][1] ))
        seg_img[:,:,2] += (segc*( colors[c][2] ))

    return(seg_img)

# %%
input_height , input_width = 224 , 224
output_height , output_width = 224 , 224


ldseg = np.array(os.listdir(dir_seg))
for fnm in ldseg[np.random.choice(len(ldseg),3,replace=False)]:
    fnm = fnm.split(".")[0]
    seg = cv2.imread(dir_seg + fnm + ".png") # (360, 480, 3)
    img_is = cv2.imread(dir_img + fnm + ".png")
    seg_img = give_color_to_seg_img(seg,n_classes)

    fig = plt.figure(figsize=(20,40))
    ax = fig.add_subplot(1,4,1)
    ax.imshow(seg_img)
    
    ax = fig.add_subplot(1,4,2)
    ax.imshow(img_is/255.0)
    ax.set_title("original image {}".format(img_is.shape[:2]))
    
    ax = fig.add_subplot(1,4,3)
    ax.imshow(cv2.resize(seg_img,(input_height , input_width)))
    
    ax = fig.add_subplot(1,4,4)
    ax.imshow(cv2.resize(img_is,(output_height , output_width))/255.0)
    ax.set_title("resized to {}".format((output_height , output_width)))
    plt.show()

# %%
def getImageArr( path , width , height ):
        img = cv2.imread(path, 1)
        img = np.float32(cv2.resize(img, ( width , height ))) / 127.5 - 1
        return img

def getSegmentationArr( path , nClasses ,  width , height  ):

    seg_labels = np.zeros((  height , width  , nClasses ))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, ( width , height ))
    img = img[:, : , 0]

    for c in range(nClasses):
        seg_labels[: , : , c ] = (img == c ).astype(int)
    ##seg_labels = np.reshape(seg_labels, ( width*height,nClasses  ))
    return seg_labels

# %% [markdown]
# Resize all the images. We have 367 images in this dataset

# %%
images = os.listdir(dir_img)
images.sort()
segmentations  = os.listdir(dir_seg)
segmentations.sort()
    
X = []
Y = []
for im , seg in zip(images,segmentations) :
    X.append( getImageArr(dir_img + im , input_width , input_height )  )
    Y.append( getSegmentationArr( dir_seg + seg , n_classes , output_width , output_height )  )

X, Y = np.array(X) , np.array(Y)
print(X.shape,Y.shape)
# Out:
# (367, 224, 224, 3) (367, 224, 224, 12)

# %% [markdown]
# Import Keras and Tensorflow to develop deep learning FCN models

# %%
## Import usual libraries
import tensorflow as tf
import keras, sys, time, warnings
from keras.models import *
from keras.layers import *
from keras import optimizers

# %%
print("python {}".format(sys.version))
print("keras version {}".format(keras.__version__)); del keras
print("tensorflow version {}".format(tf.__version__))
# Out:
# python 3.7.3 (default, Mar 27 2019, 22:11:17)
# [GCC 7.3.0]
# keras version 2.2.4
# tensorflow version 1.13.1

# %%
## location of VGG weights
VGG_Weights_path = "vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5"

# %%
def FCN8(nClasses ,  input_height=224, input_width=224):
    ## input_height and width must be devisible by 32 because maxpooling with filter size = (2,2) is operated 5 times,
    ## which makes the input_height and width 2^5 = 32 times smaller
    assert input_height%32 == 0
    assert input_width%32 == 0
    IMAGE_ORDERING =  "channels_last" 

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    
    ## Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1', data_format=IMAGE_ORDERING )(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool', data_format=IMAGE_ORDERING )(x)
    f1 = x
    
    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool', data_format=IMAGE_ORDERING )(x)
    f2 = x

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3', data_format=IMAGE_ORDERING )(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool', data_format=IMAGE_ORDERING )(x)
    pool3 = x

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3', data_format=IMAGE_ORDERING )(x)
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool', data_format=IMAGE_ORDERING )(x)## (None, 14, 14, 512) 

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1', data_format=IMAGE_ORDERING )(pool4)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2', data_format=IMAGE_ORDERING )(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3', data_format=IMAGE_ORDERING )(x)
    pool5 = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool', data_format=IMAGE_ORDERING )(x)## (None, 7, 7, 512)

    #x = Flatten(name='flatten')(x)
    #x = Dense(4096, activation='relu', name='fc1')(x)
    # <--> o = ( Conv2D( 4096 , ( 7 , 7 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(4096, activation='relu', name='fc2')(x)
    # <--> o = ( Conv2D( 4096 , ( 1 , 1 ) , activation='relu' , padding='same', data_format=IMAGE_ORDERING))(o)   
    # assuming that the input_height = input_width = 224 as in VGG data
    
    #x = Dense(1000 , activation='softmax', name='predictions')(x)
    # <--> o = ( Conv2D( nClasses ,  ( 1 , 1 ) ,kernel_initializer='he_normal' , data_format=IMAGE_ORDERING))(o)
    # assuming that the input_height = input_width = 224 as in VGG data
    
    
    vgg  = Model(  img_input , pool5  )
    vgg.load_weights(VGG_Weights_path) ## loading VGG weights for the encoder parts of FCN8
    
    n = 4096
    o = ( Conv2D( n , ( 7 , 7 ) , activation='relu' , padding='same', name="conv6", data_format=IMAGE_ORDERING))(pool5)
    conv7 = ( Conv2D( n , ( 1 , 1 ) , activation='relu' , padding='same', name="conv7", data_format=IMAGE_ORDERING))(o)
    
    
    ## 4 times upsamping for pool4 layer
    conv7_4 = Conv2DTranspose( nClasses , kernel_size=(4,4) ,  strides=(4,4) , use_bias=False, data_format=IMAGE_ORDERING )(conv7)
    ## (None, 224, 224, 10)
    ## 2 times upsampling for pool411
    pool411 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool4_11", data_format=IMAGE_ORDERING))(pool4)
    
    
    
    pool411_2 = (Conv2DTranspose( nClasses , kernel_size=(2,2) ,  strides=(2,2) , use_bias=False, data_format=IMAGE_ORDERING ))(pool411)
    
    pool311 = ( Conv2D( nClasses , ( 1 , 1 ) , activation='relu' , padding='same', name="pool3_11", data_format=IMAGE_ORDERING))(pool3)
        
    o = Add(name="add")([pool411_2, pool311, conv7_4 ])
    o = Conv2DTranspose( nClasses , kernel_size=(8,8) ,  strides=(8,8) , use_bias=False, data_format=IMAGE_ORDERING )(o)
    o = (Activation('softmax'))(o)
    
    model = Model(img_input, o)

    return model

# %%
model = FCN8(nClasses     = n_classes,  
             input_height = 224, 
             input_width  = 224)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# conv6 (Conv2D)                  (None, 7, 7, 4096)   102764544   block5_pool[0][0]
# __________________________________________________________________________________________________
# pool4_11 (Conv2D)               (None, 14, 14, 12)   6156        block4_pool[0][0]
# __________________________________________________________________________________________________
# conv7 (Conv2D)                  (None, 7, 7, 4096)   16781312    conv6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 28, 28, 12)   576         pool4_11[0][0]
# __________________________________________________________________________________________________
# pool3_11 (Conv2D)               (None, 28, 28, 12)   3084        block3_pool[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 28, 28, 12)   786432      conv7[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 28, 28, 12)   0           conv2d_transpose_2[0][0]
#                                                                  pool3_11[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 224, 224, 12) 9216        add[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 12) 0           conv2d_transpose_3[0][0]
# ==================================================================================================
# Total params: 135,066,008
# Trainable params: 135,066,008
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Split between training and testing data

# %%
train_rate = 0.85
index_train = np.random.choice(X.shape[0],int(X.shape[0]*train_rate),replace=False)
index_test  = list(set(range(X.shape[0])) - set(index_train))
                            
X, Y = shuffle(X,Y)
X_train, y_train = X[index_train],Y[index_train]
X_test, y_test = X[index_test],Y[index_test]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (311, 224, 224, 3) (311, 224, 224, 12)
# (56, 224, 224, 3) (56, 224, 224, 12)

# %% [markdown]
# Training starts here

# %%
sgd = optimizers.SGD(lr=1E-2, decay=5**(-4), momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

hist1 = model.fit(X_train,y_train,
                  validation_data=(X_test,y_test),
                  batch_size=32,epochs=200,verbose=2)
# Out:
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/edu/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/pirl/anaconda3/envs/edu/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 311 samples, validate on 56 samples
# Epoch 1/200
#  - 21s - loss: 2.6352 - acc: 0.0860 - val_loss: 2.4849 - val_acc: 0.0868
# Epoch 2/200
#  - 5s - loss: 2.4834 - acc: 0.0932 - val_loss: 2.4808 - val_acc: 0.1012
# Epoch 3/200
#  - 5s - loss: 2.4791 - acc: 0.1055 - val_loss: 2.4749 - val_acc: 0.1149
# Epoch 4/200
#  - 5s - loss: 2.4708 - acc: 0.1227 - val_loss: 2.4607 - val_acc: 0.1344
# Epoch 5/200
#  - 5s - loss: 2.4488 - acc: 0.1423 - val_loss: 2.4201 - val_acc: 0.1602
# Epoch 6/200
#  - 5s - loss: 2.3818 - acc: 0.1809 - val_loss: 2.2912 - val_acc: 0.2248
# Epoch 7/200
#  - 5s - loss: 2.2458 - acc: 0.2507 - val_loss: 2.0546 - val_acc: 0.2988
# Epoch 8/200
#  - 5s - loss: 2.0018 - acc: 0.3143 - val_loss: 1.9208 - val_acc: 0.3232
# Epoch 9/200
#  - 5s - loss: 1.8738 - acc: 0.3240 - val_loss: 1.7864 - val_acc: 0.3338
# Epoch 10/200
#  - 5s - loss: 1.7681 - acc: 0.3437 - val_loss: 1.6876 - val_acc: 0.3833
# Epoch 11/200
#  - 5s - loss: 1.6506 - acc: 0.4288 - val_loss: 1.5073 - val_acc: 0.5137
# Epoch 12/200
#  - 5s - loss: 1.4861 - acc: 0.5554 - val_loss: 1.2543 - val_acc: 0.6389
# Epoch 13/200
#  - 5s - loss: 1.2305 - acc: 0.6425 - val_loss: 1.0933 - val_acc: 0.6846
# Epoch 14/200
#  - 5s - loss: 1.1161 - acc: 0.6648 - val_loss: 1.0220 - val_acc: 0.6934
# Epoch 15/200
#  - 5s - loss: 1.0545 - acc: 0.6718 - val_loss: 0.9856 - val_acc: 0.6989
# Epoch 16/200
#  - 5s - loss: 1.0271 - acc: 0.6759 - val_loss: 0.9594 - val_acc: 0.7026
# Epoch 17/200
#  - 5s - loss: 1.0015 - acc: 0.6792 - val_loss: 0.9489 - val_acc: 0.7042
# Epoch 18/200
#  - 5s - loss: 0.9878 - acc: 0.6814 - val_loss: 0.9351 - val_acc: 0.7030
# Epoch 19/200
#  - 5s - loss: 0.9656 - acc: 0.6843 - val_loss: 0.9060 - val_acc: 0.7071
# Epoch 20/200
#  - 5s - loss: 0.9440 - acc: 0.6885 - val_loss: 0.8801 - val_acc: 0.7140
# Epoch 21/200
#  - 5s - loss: 0.9231 - acc: 0.6939 - val_loss: 0.8620 - val_acc: 0.7220
# Epoch 22/200
#  - 5s - loss: 0.9125 - acc: 0.7008 - val_loss: 0.9208 - val_acc: 0.7178
# Epoch 23/200
#  - 5s - loss: 0.9277 - acc: 0.7058 - val_loss: 0.8291 - val_acc: 0.7313
# Epoch 24/200
#  - 5s - loss: 0.8711 - acc: 0.7200 - val_loss: 0.8275 - val_acc: 0.7595
# Epoch 25/200
#  - 5s - loss: 0.8649 - acc: 0.7334 - val_loss: 0.8455 - val_acc: 0.7506
# Epoch 26/200
#  - 5s - loss: 0.8596 - acc: 0.7377 - val_loss: 0.7893 - val_acc: 0.7702
# Epoch 27/200
#  - 5s - loss: 0.8362 - acc: 0.7489 - val_loss: 0.7712 - val_acc: 0.7704
# Epoch 28/200
#  - 5s - loss: 0.8409 - acc: 0.7490 - val_loss: 0.7627 - val_acc: 0.7695
# Epoch 29/200
#  - 5s - loss: 0.8050 - acc: 0.7609 - val_loss: 0.7545 - val_acc: 0.7819
# Epoch 30/200
#  - 5s - loss: 0.8256 - acc: 0.7519 - val_loss: 0.7531 - val_acc: 0.7849
# Epoch 31/200
#  - 5s - loss: 0.7916 - acc: 0.7680 - val_loss: 0.7884 - val_acc: 0.7664
# Epoch 32/200
#  - 5s - loss: 0.7804 - acc: 0.7714 - val_loss: 0.7285 - val_acc: 0.7902
# Epoch 33/200
#  - 5s - loss: 0.8110 - acc: 0.7593 - val_loss: 0.7928 - val_acc: 0.7581
# Epoch 34/200
#  - 5s - loss: 0.7761 - acc: 0.7709 - val_loss: 0.7197 - val_acc: 0.7911
# Epoch 35/200
#  - 5s - loss: 0.7747 - acc: 0.7706 - val_loss: 0.7268 - val_acc: 0.7856
# Epoch 36/200
#  - 5s - loss: 0.7522 - acc: 0.7785 - val_loss: 0.7114 - val_acc: 0.7967
# Epoch 37/200
#  - 5s - loss: 0.7562 - acc: 0.7769 - val_loss: 0.7024 - val_acc: 0.7967
# Epoch 38/200
#  - 5s - loss: 0.7394 - acc: 0.7835 - val_loss: 0.7014 - val_acc: 0.7971
# Epoch 39/200
#  - 5s - loss: 0.7384 - acc: 0.7823 - val_loss: 0.7625 - val_acc: 0.7729
# Epoch 40/200
#  - 5s - loss: 0.7460 - acc: 0.7801 - val_loss: 0.7055 - val_acc: 0.7945
# Epoch 41/200
#  - 5s - loss: 0.7397 - acc: 0.7832 - val_loss: 0.7167 - val_acc: 0.7908
# Epoch 42/200
#  - 5s - loss: 0.7215 - acc: 0.7895 - val_loss: 0.6782 - val_acc: 0.8052
# Epoch 43/200
#  - 5s - loss: 0.7084 - acc: 0.7939 - val_loss: 0.6991 - val_acc: 0.7976
# Epoch 44/200
#  - 5s - loss: 0.7495 - acc: 0.7789 - val_loss: 0.6823 - val_acc: 0.8027
# Epoch 45/200
#  - 5s - loss: 0.7059 - acc: 0.7948 - val_loss: 0.6710 - val_acc: 0.8081
# Epoch 46/200
#  - 5s - loss: 0.7097 - acc: 0.7929 - val_loss: 0.6686 - val_acc: 0.8078
# Epoch 47/200
#  - 5s - loss: 0.6976 - acc: 0.7973 - val_loss: 0.6753 - val_acc: 0.8044
# Epoch 48/200
#  - 5s - loss: 0.7076 - acc: 0.7938 - val_loss: 0.6753 - val_acc: 0.8058
# Epoch 49/200
#  - 5s - loss: 0.6998 - acc: 0.7961 - val_loss: 0.6538 - val_acc: 0.8120
# Epoch 50/200
#  - 5s - loss: 0.6816 - acc: 0.8024 - val_loss: 0.6560 - val_acc: 0.8127
# Epoch 51/200
#  - 5s - loss: 0.6843 - acc: 0.8023 - val_loss: 0.6552 - val_acc: 0.8124
# Epoch 52/200
#  - 5s - loss: 0.6693 - acc: 0.8081 - val_loss: 0.6407 - val_acc: 0.8178
# Epoch 53/200
#  - 5s - loss: 0.6685 - acc: 0.8081 - val_loss: 0.6641 - val_acc: 0.8097
# Epoch 54/200
#  - 5s - loss: 0.7154 - acc: 0.7908 - val_loss: 0.6396 - val_acc: 0.8172
# Epoch 55/200
#  - 5s - loss: 0.6622 - acc: 0.8107 - val_loss: 0.6376 - val_acc: 0.8198
# Epoch 56/200
#  - 5s - loss: 0.6553 - acc: 0.8125 - val_loss: 0.6416 - val_acc: 0.8181
# Epoch 57/200
#  - 5s - loss: 0.6683 - acc: 0.8081 - val_loss: 0.6235 - val_acc: 0.8242
# Epoch 58/200
#  - 5s - loss: 0.6429 - acc: 0.8174 - val_loss: 0.6172 - val_acc: 0.8267
# Epoch 59/200
#  - 5s - loss: 0.6416 - acc: 0.8173 - val_loss: 0.6238 - val_acc: 0.8243
# Epoch 60/200
#  - 5s - loss: 0.6401 - acc: 0.8178 - val_loss: 0.6070 - val_acc: 0.8295
# Epoch 61/200
#  - 5s - loss: 0.6411 - acc: 0.8168 - val_loss: 0.6052 - val_acc: 0.8295
# Epoch 62/200
#  - 5s - loss: 0.6431 - acc: 0.8165 - val_loss: 0.6057 - val_acc: 0.8297
# Epoch 63/200
#  - 5s - loss: 0.6474 - acc: 0.8148 - val_loss: 0.6051 - val_acc: 0.8293
# Epoch 64/200
#  - 5s - loss: 0.6206 - acc: 0.8245 - val_loss: 0.5953 - val_acc: 0.8328
# Epoch 65/200
#  - 5s - loss: 0.6135 - acc: 0.8265 - val_loss: 0.6004 - val_acc: 0.8318
# Epoch 66/200
#  - 5s - loss: 0.6096 - acc: 0.8282 - val_loss: 0.6160 - val_acc: 0.8260
# Epoch 67/200
#  - 5s - loss: 0.6365 - acc: 0.8193 - val_loss: 0.5932 - val_acc: 0.8322
# Epoch 68/200
#  - 5s - loss: 0.6054 - acc: 0.8287 - val_loss: 0.5878 - val_acc: 0.8368
# Epoch 69/200
#  - 5s - loss: 0.6124 - acc: 0.8263 - val_loss: 0.5830 - val_acc: 0.8380
# Epoch 70/200
#  - 5s - loss: 0.5988 - acc: 0.8307 - val_loss: 0.5874 - val_acc: 0.8349
# Epoch 71/200
#  - 5s - loss: 0.5907 - acc: 0.8333 - val_loss: 0.5796 - val_acc: 0.8381
# Epoch 72/200
#  - 5s - loss: 0.6070 - acc: 0.8284 - val_loss: 0.5848 - val_acc: 0.8357
# Epoch 73/200
#  - 5s - loss: 0.6107 - acc: 0.8269 - val_loss: 0.5741 - val_acc: 0.8385
# Epoch 74/200
#  - 5s - loss: 0.5844 - acc: 0.8353 - val_loss: 0.5781 - val_acc: 0.8374
# Epoch 75/200
#  - 5s - loss: 0.5851 - acc: 0.8342 - val_loss: 0.5858 - val_acc: 0.8391
# Epoch 76/200
#  - 5s - loss: 0.5871 - acc: 0.8346 - val_loss: 0.5631 - val_acc: 0.8420
# Epoch 77/200
#  - 5s - loss: 0.5743 - acc: 0.8379 - val_loss: 0.5593 - val_acc: 0.8436
# Epoch 78/200
#  - 5s - loss: 0.5792 - acc: 0.8362 - val_loss: 0.5643 - val_acc: 0.8421
# Epoch 79/200
#  - 5s - loss: 0.5709 - acc: 0.8386 - val_loss: 0.5645 - val_acc: 0.8415
# Epoch 80/200
#  - 5s - loss: 0.5807 - acc: 0.8357 - val_loss: 0.6462 - val_acc: 0.8155
# Epoch 81/200
#  - 5s - loss: 0.5811 - acc: 0.8345 - val_loss: 0.5530 - val_acc: 0.8449
# Epoch 82/200
#  - 5s - loss: 0.5617 - acc: 0.8416 - val_loss: 0.5590 - val_acc: 0.8449
# Epoch 83/200
#  - 5s - loss: 0.5622 - acc: 0.8415 - val_loss: 0.5487 - val_acc: 0.8459
# Epoch 84/200
#  - 5s - loss: 0.5574 - acc: 0.8425 - val_loss: 0.5544 - val_acc: 0.8449
# Epoch 85/200
#  - 5s - loss: 0.5621 - acc: 0.8414 - val_loss: 0.5758 - val_acc: 0.8390
# Epoch 86/200
#  - 5s - loss: 0.5754 - acc: 0.8372 - val_loss: 0.5471 - val_acc: 0.8467
# Epoch 87/200
#  - 5s - loss: 0.5554 - acc: 0.8436 - val_loss: 0.5452 - val_acc: 0.8477
# Epoch 88/200
#  - 5s - loss: 0.5518 - acc: 0.8441 - val_loss: 0.5400 - val_acc: 0.8480
# Epoch 89/200
#  - 5s - loss: 0.5513 - acc: 0.8447 - val_loss: 0.5450 - val_acc: 0.8467
# Epoch 90/200
#  - 5s - loss: 0.5433 - acc: 0.8469 - val_loss: 0.5372 - val_acc: 0.8490
# Epoch 91/200
#  - 5s - loss: 0.5423 - acc: 0.8476 - val_loss: 0.5441 - val_acc: 0.8465
# Epoch 92/200
#  - 5s - loss: 0.5459 - acc: 0.8460 - val_loss: 0.5352 - val_acc: 0.8488
# Epoch 93/200
#  - 5s - loss: 0.5391 - acc: 0.8479 - val_loss: 0.5389 - val_acc: 0.8487
# Epoch 94/200
#  - 5s - loss: 0.5586 - acc: 0.8420 - val_loss: 0.5736 - val_acc: 0.8388
# Epoch 95/200
#  - 5s - loss: 0.5422 - acc: 0.8477 - val_loss: 0.5351 - val_acc: 0.8494
# Epoch 96/200
#  - 5s - loss: 0.5326 - acc: 0.8504 - val_loss: 0.5332 - val_acc: 0.8497
# Epoch 97/200
#  - 5s - loss: 0.5332 - acc: 0.8498 - val_loss: 0.5905 - val_acc: 0.8340
# Epoch 98/200
#  - 5s - loss: 0.5517 - acc: 0.8439 - val_loss: 0.5338 - val_acc: 0.8507
# Epoch 99/200
#  - 5s - loss: 0.5297 - acc: 0.8508 - val_loss: 0.5472 - val_acc: 0.8462
# Epoch 100/200
#  - 5s - loss: 0.5269 - acc: 0.8519 - val_loss: 0.5286 - val_acc: 0.8508
# Epoch 101/200
#  - 5s - loss: 0.5357 - acc: 0.8490 - val_loss: 0.5505 - val_acc: 0.8443
# Epoch 102/200
#  - 5s - loss: 0.5276 - acc: 0.8516 - val_loss: 0.5222 - val_acc: 0.8532
# Epoch 103/200
#  - 5s - loss: 0.5187 - acc: 0.8545 - val_loss: 0.5237 - val_acc: 0.8515
# Epoch 104/200
#  - 5s - loss: 0.5189 - acc: 0.8536 - val_loss: 0.5306 - val_acc: 0.8498
# Epoch 105/200
#  - 5s - loss: 0.5213 - acc: 0.8535 - val_loss: 0.5392 - val_acc: 0.8478
# Epoch 106/200
#  - 5s - loss: 0.5432 - acc: 0.8451 - val_loss: 0.5214 - val_acc: 0.8515
# Epoch 107/200
#  - 5s - loss: 0.5135 - acc: 0.8555 - val_loss: 0.5163 - val_acc: 0.8544
# Epoch 108/200
#  - 5s - loss: 0.5166 - acc: 0.8546 - val_loss: 0.5329 - val_acc: 0.8494
# Epoch 109/200
#  - 5s - loss: 0.5239 - acc: 0.8521 - val_loss: 0.5225 - val_acc: 0.8525
# Epoch 110/200
#  - 5s - loss: 0.5096 - acc: 0.8568 - val_loss: 0.5140 - val_acc: 0.8554
# Epoch 111/200
#  - 5s - loss: 0.5117 - acc: 0.8557 - val_loss: 0.5338 - val_acc: 0.8479
# Epoch 112/200
#  - 5s - loss: 0.5124 - acc: 0.8556 - val_loss: 0.5269 - val_acc: 0.8511
# Epoch 113/200
#  - 5s - loss: 0.5066 - acc: 0.8575 - val_loss: 0.5177 - val_acc: 0.8540
# Epoch 114/200
#  - 5s - loss: 0.5040 - acc: 0.8580 - val_loss: 0.5202 - val_acc: 0.8541
# Epoch 115/200
#  - 5s - loss: 0.5058 - acc: 0.8579 - val_loss: 0.5108 - val_acc: 0.8554
# Epoch 116/200
#  - 5s - loss: 0.4980 - acc: 0.8601 - val_loss: 0.5303 - val_acc: 0.8505
# Epoch 117/200
#  - 5s - loss: 0.5135 - acc: 0.8542 - val_loss: 0.5092 - val_acc: 0.8564
# Epoch 118/200
#  - 5s - loss: 0.4993 - acc: 0.8594 - val_loss: 0.5124 - val_acc: 0.8562
# Epoch 119/200
#  - 5s - loss: 0.4988 - acc: 0.8594 - val_loss: 0.5163 - val_acc: 0.8550
# Epoch 120/200
#  - 5s - loss: 0.4993 - acc: 0.8596 - val_loss: 0.5053 - val_acc: 0.8574
# Epoch 121/200
#  - 5s - loss: 0.4900 - acc: 0.8623 - val_loss: 0.5044 - val_acc: 0.8574
# Epoch 122/200
#  - 5s - loss: 0.4922 - acc: 0.8615 - val_loss: 0.5096 - val_acc: 0.8559
# Epoch 123/200
#  - 5s - loss: 0.5027 - acc: 0.8578 - val_loss: 0.5037 - val_acc: 0.8582
# Epoch 124/200
#  - 5s - loss: 0.4932 - acc: 0.8612 - val_loss: 0.5027 - val_acc: 0.8585
# Epoch 125/200
#  - 5s - loss: 0.4889 - acc: 0.8626 - val_loss: 0.5032 - val_acc: 0.8576
# Epoch 126/200
#  - 5s - loss: 0.4951 - acc: 0.8599 - val_loss: 0.5020 - val_acc: 0.8581
# Epoch 127/200
#  - 5s - loss: 0.4883 - acc: 0.8625 - val_loss: 0.5004 - val_acc: 0.8581
# Epoch 128/200
#  - 5s - loss: 0.4806 - acc: 0.8651 - val_loss: 0.5131 - val_acc: 0.8550
# Epoch 129/200
#  - 5s - loss: 0.4847 - acc: 0.8635 - val_loss: 0.5063 - val_acc: 0.8575
# Epoch 130/200
#  - 5s - loss: 0.4856 - acc: 0.8631 - val_loss: 0.5022 - val_acc: 0.8592
# Epoch 131/200
#  - 5s - loss: 0.4891 - acc: 0.8623 - val_loss: 0.5101 - val_acc: 0.8568
# Epoch 132/200
#  - 5s - loss: 0.4789 - acc: 0.8653 - val_loss: 0.4951 - val_acc: 0.8602
# Epoch 133/200
#  - 5s - loss: 0.4809 - acc: 0.8646 - val_loss: 0.4971 - val_acc: 0.8593
# Epoch 134/200
#  - 5s - loss: 0.4741 - acc: 0.8667 - val_loss: 0.4959 - val_acc: 0.8597
# Epoch 135/200
#  - 5s - loss: 0.4706 - acc: 0.8679 - val_loss: 0.4973 - val_acc: 0.8592
# Epoch 136/200
#  - 5s - loss: 0.4937 - acc: 0.8601 - val_loss: 0.4943 - val_acc: 0.8605
# Epoch 137/200
#  - 5s - loss: 0.4720 - acc: 0.8670 - val_loss: 0.4953 - val_acc: 0.8605
# Epoch 138/200
#  - 5s - loss: 0.4881 - acc: 0.8616 - val_loss: 0.4915 - val_acc: 0.8609
# Epoch 139/200
#  - 5s - loss: 0.4712 - acc: 0.8676 - val_loss: 0.4920 - val_acc: 0.8612
# Epoch 140/200
#  - 5s - loss: 0.4771 - acc: 0.8655 - val_loss: 0.5247 - val_acc: 0.8531
# Epoch 141/200
#  - 5s - loss: 0.4775 - acc: 0.8657 - val_loss: 0.4897 - val_acc: 0.8616
# Epoch 142/200
#  - 5s - loss: 0.4662 - acc: 0.8690 - val_loss: 0.4865 - val_acc: 0.8628
# Epoch 143/200
#  - 5s - loss: 0.4617 - acc: 0.8704 - val_loss: 0.4975 - val_acc: 0.8592
# Epoch 144/200
#  - 5s - loss: 0.4658 - acc: 0.8688 - val_loss: 0.4914 - val_acc: 0.8622
# Epoch 145/200
#  - 5s - loss: 0.4603 - acc: 0.8710 - val_loss: 0.5026 - val_acc: 0.8588
# Epoch 146/200
#  - 5s - loss: 0.4643 - acc: 0.8695 - val_loss: 0.5100 - val_acc: 0.8555
# Epoch 147/200
#  - 5s - loss: 0.4823 - acc: 0.8621 - val_loss: 0.4878 - val_acc: 0.8619
# Epoch 148/200
#  - 5s - loss: 0.4579 - acc: 0.8716 - val_loss: 0.4924 - val_acc: 0.8613
# Epoch 149/200
#  - 5s - loss: 0.4654 - acc: 0.8691 - val_loss: 0.4836 - val_acc: 0.8639
# Epoch 150/200
#  - 5s - loss: 0.4533 - acc: 0.8734 - val_loss: 0.4858 - val_acc: 0.8633
# Epoch 151/200
#  - 5s - loss: 0.4701 - acc: 0.8678 - val_loss: 0.4833 - val_acc: 0.8638
# Epoch 152/200
#  - 5s - loss: 0.4552 - acc: 0.8722 - val_loss: 0.4928 - val_acc: 0.8617
# Epoch 153/200
#  - 5s - loss: 0.4530 - acc: 0.8733 - val_loss: 0.4934 - val_acc: 0.8608
# Epoch 154/200
#  - 5s - loss: 0.4586 - acc: 0.8714 - val_loss: 0.4994 - val_acc: 0.8594
# Epoch 155/200
#  - 5s - loss: 0.4685 - acc: 0.8684 - val_loss: 0.4844 - val_acc: 0.8630
# Epoch 156/200
#  - 5s - loss: 0.4507 - acc: 0.8737 - val_loss: 0.4855 - val_acc: 0.8635
# Epoch 157/200
#  - 5s - loss: 0.4509 - acc: 0.8738 - val_loss: 0.4960 - val_acc: 0.8602
# Epoch 158/200
#  - 5s - loss: 0.4520 - acc: 0.8735 - val_loss: 0.4817 - val_acc: 0.8640
# Epoch 159/200
#  - 5s - loss: 0.4505 - acc: 0.8739 - val_loss: 0.4993 - val_acc: 0.8585
# Epoch 160/200
#  - 5s - loss: 0.4504 - acc: 0.8736 - val_loss: 0.4878 - val_acc: 0.8634
# Epoch 161/200
#  - 5s - loss: 0.4498 - acc: 0.8742 - val_loss: 0.4812 - val_acc: 0.8644
# Epoch 162/200
#  - 5s - loss: 0.4436 - acc: 0.8760 - val_loss: 0.5186 - val_acc: 0.8549
# Epoch 163/200
#  - 5s - loss: 0.4607 - acc: 0.8703 - val_loss: 0.4824 - val_acc: 0.8634
# Epoch 164/200
#  - 5s - loss: 0.4401 - acc: 0.8769 - val_loss: 0.4777 - val_acc: 0.8653
# Epoch 165/200
#  - 5s - loss: 0.4459 - acc: 0.8752 - val_loss: 0.4951 - val_acc: 0.8606
# Epoch 166/200
#  - 5s - loss: 0.4401 - acc: 0.8770 - val_loss: 0.4826 - val_acc: 0.8648
# Epoch 167/200
#  - 5s - loss: 0.4386 - acc: 0.8778 - val_loss: 0.4871 - val_acc: 0.8633
# Epoch 168/200
#  - 5s - loss: 0.4530 - acc: 0.8731 - val_loss: 0.4814 - val_acc: 0.8645
# Epoch 169/200
#  - 5s - loss: 0.4385 - acc: 0.8774 - val_loss: 0.4783 - val_acc: 0.8657
# Epoch 170/200
#  - 5s - loss: 0.4359 - acc: 0.8783 - val_loss: 0.4905 - val_acc: 0.8624
# Epoch 171/200
#  - 5s - loss: 0.4432 - acc: 0.8755 - val_loss: 0.4790 - val_acc: 0.8653
# Epoch 172/200
#  - 5s - loss: 0.4331 - acc: 0.8794 - val_loss: 0.4808 - val_acc: 0.8641
# Epoch 173/200
#  - 5s - loss: 0.4362 - acc: 0.8781 - val_loss: 0.4798 - val_acc: 0.8654
# Epoch 174/200
#  - 5s - loss: 0.4340 - acc: 0.8789 - val_loss: 0.4809 - val_acc: 0.8650
# Epoch 175/200
#  - 5s - loss: 0.4295 - acc: 0.8804 - val_loss: 0.4787 - val_acc: 0.8652
# Epoch 176/200
#  - 5s - loss: 0.4419 - acc: 0.8765 - val_loss: 0.5141 - val_acc: 0.8567
# Epoch 177/200
#  - 5s - loss: 0.4420 - acc: 0.8759 - val_loss: 0.4747 - val_acc: 0.8665
# Epoch 178/200
#  - 5s - loss: 0.4312 - acc: 0.8797 - val_loss: 0.4994 - val_acc: 0.8601
# Epoch 179/200
#  - 5s - loss: 0.4297 - acc: 0.8800 - val_loss: 0.4842 - val_acc: 0.8635
# Epoch 180/200
#  - 5s - loss: 0.4311 - acc: 0.8800 - val_loss: 0.4737 - val_acc: 0.8668
# Epoch 181/200
#  - 5s - loss: 0.4236 - acc: 0.8821 - val_loss: 0.4895 - val_acc: 0.8630
# Epoch 182/200
#  - 5s - loss: 0.4356 - acc: 0.8776 - val_loss: 0.5242 - val_acc: 0.8533
# Epoch 183/200
#  - 5s - loss: 0.4444 - acc: 0.8746 - val_loss: 0.4732 - val_acc: 0.8666
# Epoch 184/200
#  - 5s - loss: 0.4214 - acc: 0.8827 - val_loss: 0.4709 - val_acc: 0.8676
# Epoch 185/200
#  - 5s - loss: 0.4220 - acc: 0.8827 - val_loss: 0.4749 - val_acc: 0.8664
# Epoch 186/200
#  - 5s - loss: 0.4237 - acc: 0.8816 - val_loss: 0.4852 - val_acc: 0.8632
# Epoch 187/200
#  - 5s - loss: 0.4314 - acc: 0.8790 - val_loss: 0.4749 - val_acc: 0.8663
# Epoch 188/200
#  - 5s - loss: 0.4226 - acc: 0.8819 - val_loss: 0.4900 - val_acc: 0.8629
# Epoch 189/200
#  - 5s - loss: 0.4190 - acc: 0.8835 - val_loss: 0.4805 - val_acc: 0.8640
# Epoch 190/200
#  - 5s - loss: 0.4227 - acc: 0.8820 - val_loss: 0.4746 - val_acc: 0.8662
# Epoch 191/200
#  - 5s - loss: 0.4166 - acc: 0.8843 - val_loss: 0.4781 - val_acc: 0.8660
# Epoch 192/200
#  - 5s - loss: 0.4246 - acc: 0.8812 - val_loss: 0.4865 - val_acc: 0.8635
# Epoch 193/200
#  - 5s - loss: 0.4203 - acc: 0.8826 - val_loss: 0.4706 - val_acc: 0.8683
# Epoch 194/200
#  - 5s - loss: 0.4171 - acc: 0.8839 - val_loss: 0.4671 - val_acc: 0.8691
# Epoch 195/200
#  - 5s - loss: 0.4158 - acc: 0.8840 - val_loss: 0.4677 - val_acc: 0.8691
# Epoch 196/200
#  - 5s - loss: 0.4242 - acc: 0.8815 - val_loss: 0.4818 - val_acc: 0.8645
# Epoch 197/200
#  - 5s - loss: 0.4178 - acc: 0.8834 - val_loss: 0.4673 - val_acc: 0.8694
# Epoch 198/200
#  - 5s - loss: 0.4091 - acc: 0.8864 - val_loss: 0.4697 - val_acc: 0.8687
# Epoch 199/200
#  - 5s - loss: 0.4067 - acc: 0.8872 - val_loss: 0.4826 - val_acc: 0.8655
# Epoch 200/200
#  - 5s - loss: 0.4522 - acc: 0.8727 - val_loss: 0.5243 - val_acc: 0.8554

# %% [markdown]
# Plot the change in loss over epochs

# %%
for key in ['loss', 'val_loss']:
    plt.plot(hist1.history[key],label=key)
plt.legend()
plt.show()

# %% [markdown]
# Calculate intersection over union for each segmentation class

# %%
y_pred = model.predict(X_test)
y_predi = np.argmax(y_pred, axis=3)
y_testi = np.argmax(y_test, axis=3)
print(y_testi.shape,y_predi.shape)
# Out:
# (56, 224, 224) (56, 224, 224)

# %%
def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)

    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi==c) )
        FP = np.sum( (Yi != c)&(y_predi==c) )
        FN = np.sum( (Yi == c)&(y_predi != c)) 
        IoU = TP/float(TP + FP + FN)
        print("class {:02.0f}: #TP={:6.0f}, #FP={:6.0f}, #FN={:5.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))

# %%
IoU(y_testi,y_predi)
# Out:
# class 00: #TP=417980, #FP= 37915, #FN=23029, IoU=0.873
# class 01: #TP=686097, #FP=196706, #FN=23446, IoU=0.757
# class 02: #TP=    11, #FP=   135, #FN=31401, IoU=0.000
# class 03: #TP=868878, #FP= 43424, #FN=32687, IoU=0.919
# class 04: #TP= 86149, #FP= 44373, #FN=44535, IoU=0.492
# class 05: #TP=170555, #FP= 30678, #FN=62125, IoU=0.648
# class 06: #TP=    47, #FP=   496, #FN=29963, IoU=0.002
# class 07: #TP=  9363, #FP=  5522, #FN=30416, IoU=0.207
# class 08: #TP=136464, #FP= 28458, #FN=43484, IoU=0.655
# class 09: #TP=    38, #FP=   348, #FN=21316, IoU=0.002
# class 10: #TP=    63, #FP=   202, #FN=10815, IoU=0.006
# class 11: #TP= 27905, #FP= 18049, #FN=53089, IoU=0.282
# _________________
# Mean IoU: 0.403

# %% [markdown]
# Visualize the model performance
#
#
# Looks reasonable!

# %%
shape = (224,224)
n_classes= 10

for i in range(10):
    img_is  = (X_test[i] + 1)*(255.0/2)
    seg = y_predi[i]
    segtest = y_testi[i]

    fig = plt.figure(figsize=(10,30))    
    ax = fig.add_subplot(1,3,1)
    ax.imshow(img_is/255.0)
    ax.set_title("original")
    
    ax = fig.add_subplot(1,3,2)
    ax.imshow(give_color_to_seg_img(seg,n_classes))
    ax.set_title("predicted class")
    
    ax = fig.add_subplot(1,3,3)
    ax.imshow(give_color_to_seg_img(segtest,n_classes))
    ax.set_title("true class")
    plt.show()
